# %% [markdown]
# # Julia is fast

# %% [markdown]
# Very often, benchmarks are used to compare languages. These benchmarks can lead to long
# discussions, first as to exactly what is being benchmarked and secondly what explains the
# differences. These simple questions can sometimes get morecomplicated than you at first
# might imagine.

# %% [markdown]
# The purpose of this notebook is for you to see a simple benchmark for yourself. One can
# read the notebook and see what happend on the author's Macbook Proc with a 4-core Intel
# Core I7, or run the notebook yourself.

# %% [markdown]
# (This material began life as a wonderful lecture by Steven Johnson at MIT:
# https://github.com/stevengj/18S096/blob/master/lectures/lecture1/Boxes-and-registers.ipynb.)

# %% [markdown]
# # Outline of this notebook

# %% [markdown]
# - Define the sum function
# - Implementations & benchmarking of sum in ...
#     - C (hand-written)
#     - C (hand-written with -ffast-math)
#     - python (built-in)
#     - python (numpy)
#     - python (hand-written)
#     - Julia (hadn-written)
#     - Julia (hand-written with SIMI)
# - Summary of benchmarks

# %% [markdown]
# # `sum`: An easy enough function to understand

# %% [markdown]
# Consider the **sum** function `sum(a)`, which computes
# $$
# \mathrm{sum}(a) = \sum_{i=1}^n a+i,
# $$
# where $n$ is the length of `a`.

# %%
a = rand(10^7) # 1D vector of random numbers, uniform on [0,1)
# Out:
# 10000000-element Array{Float64,1}:
#  0.9421518831172795
#  0.5383619847527714
#  0.6351191090833375
#  0.828651353116796
#  0.8559980058738592
#  0.3065582767141011
#  0.009998860149424527
#  0.2971643293453161
#  0.4662342787820808
#  0.9582084460748801
#  0.791302214685579
#  0.30169531658697735
#  0.11145170997362253
#  ⋮
#  0.4478948303494712
#  0.3398838623856639
#  0.5109583875604391
#  0.1168524304808718
#  0.9682830675732654
#  0.59258250738102
#  0.5318230366753758
#  0.7202134719088842
#  0.9333086752737261
#  0.23229918433137842
#  0.8375948860142626
#  0.5261880980581353

# %%
sum(a)
# Out:
# 4.998715496980474e6

# %% [markdown]
# The expected result is 0.5 * 10^7, since the mean of each entry is 0.5

# %% [markdown]
# # benchmarking a few ways in a few languages

# %%
@time sum(a)
# Out:
#   0.003731 seconds (1 allocation: 16 bytes)
# 4.998715496980474e6

# %%
@time sum(a)
# Out:
#   0.003905 seconds (1 allocation: 16 bytes)
# 4.998715496980474e6

# %%
@time sum(a)
# Out:
#   0.003916 seconds (1 allocation: 16 bytes)
# 4.998715496980474e6

# %% [markdown]
# The `@time` macro can yield noisy results, so it's not our best choice for benchmarking!

# %% [markdown]
# Luckily, Julia has a `BenchmarkTools.jl` package to make benchmarking easy and accurate:

# %%
using Pkg
Pkg.add("BenchmarkTools")
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %Fetching: [======>                                  ]  12.6 %Fetching: [======>                                  ]  14.0 %Fetching: [=======>                                 ]  16.4 %Fetching: [===============>                         ]  36.1 %                   ]  50.6 %Fetching: [======================>                  ]  54.3 %Fetching: [========================>                ]  58.0 %Fetching: [=============================>           ]  72.5 %Fetching: [==============================>          ]  75.0 %Fetching: [=====================================>   ]  91.8 %Fetching: [=====================================>   ]  91.9 %Fetching: [=====================================>   ]  92.3 %Fetching: [======================================>  ]  92.5 %Fetching: [======================================>  ]  92.9 %Fetching: [=======================================> ]  95.8 %
#   Resolving package versions...
#   Installed BenchmarkTools ─ v0.5.0
#    Updating `~/.julia/environments/v1.4/Project.toml`
#   [6e4b80f9] + BenchmarkTools v0.5.0
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#   [6e4b80f9] + BenchmarkTools v0.5.0

# %%
using BenchmarkTools
# Out:
# ┌ Info: Precompiling BenchmarkTools [6e4b80f9-dd63-53aa-95a3-0cdb28fa8baf]
# └ @ Base loading.jl:1260

# %% [markdown]
# # 1. The C language

# %% [markdown]
# C is often considered the gold standard: difficult on the human, nice for the machine.
# Getting within a factor of 2 of C is often satisfying. Nonetheless, even within C, there
# are many kind of optimizations possible that a naive C writer may or may not get the
# advantage of.

# %% [markdown]
# The current author does not speak C, so he does not read the cell below, but is happy to
# know that you can put C code in a Julia session, compile it, and run it. Note that the
# `"""` wrap a multi-line string.

# %%
using Libdl
C_code = """
#include <stddef.h>
double c_sum(size_t n, double *X) {
    double s = 0.0;
    for(size_t i = 0; i < n; i++) {
        s += X[i];
    }
    return s;
}
"""
# Out:
# "#include <stddef.h>\ndouble c_sum(size_t n, double *X) {\n    double s = 0.0;\n    for(size_t i = 0; i < n; i++) {\n        s += X[i];\n    }\n    return s;\n}\n"

# %%
const Clib = tempname() # make a temporary file
# Out:
# "/var/folders/5h/tfjh0gtx6hl_b2xstfhppy5w0000gn/T/jl_G6cmer"

# %%
# pile to a shared library by piping C_code to gcc (works only if you have gcc installed):
open(`gcc -fPIC -O3 -msse4 -xc -shared -o $(Clib * "." * Libdl.dlext) -`, "w") do f
    print(f, C_code)
end

# %%
# define a Julia function that calls the C function:
c_sum(X::Array{Float64}) = ccall(("c_sum", Clib), Float64, (Csize_t, Ptr{Float64}), length(X), X)
# Out:
# c_sum (generic function with 1 method)

# %%
c_sum(a)
# Out:
# 4.998715496980621e6

# %%
c_sum(a) ≈ sum(a) # type \approx and then <TAB> to get the ≈ symbolb
# Out:
# true

# %%
c_sum(a) - sum(a)
# Out:
# 1.4621764421463013e-7

# %%
#≈  # alias for the `isapprox` function

# %%
#isapprox

# %% [markdown]
# We can now benchmark the C code directly from Julia:

# %%
c_bench = @benchmark c_sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     10.122 ms (0.00% GC)
#   median time:      10.340 ms (0.00% GC)
#   mean time:        10.443 ms (0.00% GC)
#   maximum time:     12.335 ms (0.00% GC)
#   --------------
#   samples:          479
#   evals/sample:     1

# %%
println("C: Fastest time was $(minimum(c_bench.times) / 1e6) msec")
# Out:
# C: Fastest time was 10.122299 msec

# %%
d = Dict() # a "dictionary", i.e. an associative array
d["C"] = minimum(c_bench.times) / 1e6 # in milliseconds
d
# Out:
# Dict{Any,Any} with 1 entry:
#   "C" => 10.1223

# %%
Pkg.add("Plots")
using Plots
gr()
# Out:
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#  [no changes]
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]
# Plots.GRBackend()

# %%
using Statistics # bring in statistical support for standard deviations
t = c_bench.times / 1e6 # times in milliseconds
m, σ = minimum(t), std(t)
# Out:
# (10.122299, 0.322060714234961)

# %%
histogram(t, bins=500,
    xlim=(m - 0.01, m + σ),
    xlabel="milliseconds",
    ylabel="count", label="")

# %% [markdown]
# # 2. C with -ffast-math

# %% [markdown]
# If we allow C to re-arrange the floating point operations, then it'll vectorize with SIMD
# (single instruction, multiple data) instructions.

# %%
const Clib_fastmath = tempname() # make a temporary file
# Out:
# "/var/folders/5h/tfjh0gtx6hl_b2xstfhppy5w0000gn/T/jl_b0PHDw"

# %%
# The same as above but with a -ffast-math flag addad
open(`gcc -fPIC -O3 -msse3 -xc -shared -ffast-math -o $(Clib_fastmath * "." * Libdl.dlext) -`, "w") do f
    print(f, C_code) 
end

# %%
# define a Julia function that calls the C function:
c_sum_fastmath(X::Array{Float64}) = ccall(("c_sum", Clib_fastmath), Float64, (Csize_t, Ptr{Float64}), length(X), X)
# Out:
# c_sum_fastmath (generic function with 1 method)

# %%
c_fastmath_bench = @benchmark $c_sum_fastmath($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     3.593 ms (0.00% GC)
#   median time:      3.817 ms (0.00% GC)
#   mean time:        3.909 ms (0.00% GC)
#   maximum time:     5.349 ms (0.00% GC)
#   --------------
#   samples:          1277
#   evals/sample:     1

# %%
d["C -ffast-math"] = minimum(c_fastmath_bench.times) / 1e6  # in milliseconds
# Out:
# 3.592817

# %% [markdown]
# # 3. Python's built in `sum`

# %% [markdown]
# The `PyCall` package provides a Julia interface to Python:

# %%
using Pkg; Pkg.add("PyCall")
using PyCall
# Out:
#   Resolving package versions...
#   Installed MacroTools ─ v0.5.5
#   Installed PyCall ───── v1.91.4
#    Updating `~/.julia/environments/v1.4/Project.toml`
#   [438e738f] + PyCall v1.91.4
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#   [1914dd2f] + MacroTools v0.5.5
#   [438e738f] + PyCall v1.91.4
#    Building PyCall → `~/.julia/packages/PyCall/zqDXB/deps/build.log`
# ┌ Info: Precompiling PyCall [438e738f-606a-5dbb-bf0a-cddfbfd45ab0]
# └ @ Base loading.jl:1260

# %%
# get the Python built-in "sum" function:
pysum = pybuiltin("sum")
# Out:
# PyObject <built-in function sum>

# %%
pysum(a)
# Out:
# 4.998715496980621e6

# %%
pysum(a) ≈ sum(a)
# Out:
# true

# %%
py_list_bench = @benchmark $pysum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  352 bytes
#   allocs estimate:  7
#   --------------
#   minimum time:     1.285 s (0.00% GC)
#   median time:      1.293 s (0.00% GC)
#   mean time:        1.306 s (0.00% GC)
#   maximum time:     1.351 s (0.00% GC)
#   --------------
#   samples:          4
#   evals/sample:     1

# %%
d["Python built-in"] = minimum(py_list_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 3 entries:
#   "C"               => 10.1223
#   "Python built-in" => 1285.23
#   "C -ffast-math"   => 3.59282

# %% [markdown]
# # 4. Python: `numpy`

# %% [markdown]
# ## Takes advantage of hardware "SIMD", but only works when it works.

# %% [markdown]
# `numpy` is an optimized C library, callable from Python.
# It may be installed within Julia as follows:

# %%
using Pkg; Pkg.add("Conda")
using Conda
# Out:
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#   [8f4d0f93] + Conda v1.4.1
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]

# %%
Conda.add("numpy")
# Out:
# ┌ Info: Running `conda install -y numpy` in root environment
# └ @ Conda /Users/cudachen/.julia/packages/Conda/3rPhK/src/Conda.jl:113
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
numpy_sum = pyimport("numpy")["sum"]
# Out:
# ┌ Warning: `getindex(o::PyObject, s::AbstractString)` is deprecated in favor of dot overloading (`getproperty`) so elements should now be accessed as e.g. `o."s"` instead of `o["s"]`.
# │   caller = top-level scope at In[43]:1
# └ @ Core In[43]:1
# PyObject <function sum at 0x142b27440>

# %%
py_numpy_bench = @benchmark $numpy_sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  352 bytes
#   allocs estimate:  7
#   --------------
#   minimum time:     3.622 ms (0.00% GC)
#   median time:      3.742 ms (0.00% GC)
#   mean time:        3.823 ms (0.00% GC)
#   maximum time:     5.595 ms (0.00% GC)
#   --------------
#   samples:          1306
#   evals/sample:     1

# %%
numpy_sum(a)
# Out:
# 4.998715496980472e6

# %%
numpy_sum(a) ≈ sum(a)
# Out:
# true

# %%
d["Python numpy"] = minimum(py_numpy_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 4 entries:
#   "C"               => 10.1223
#   "Python numpy"    => 3.62204
#   "Python built-in" => 1285.23
#   "C -ffast-math"   => 3.59282

# %% [markdown]
# # 5. Python, hand-written

# %%
"""py
def py_sum(A):
    s = 0.0
    for a in A:
        s += a
    return s
"""
# Out:
# "py\ndef py_sum(A):\n    s = 0.0\n    for a in A:\n        s += a\n    return s\n"

# %%
#sum_py = "py_sum"

# %%
#py_hand = @benchmark $sum_py($a)

# %%
#sum_py(a)

# %%
#sum_py(a) ≈ sum(a)

# %%
#d["Python hand-written"] = minimum(py_hand.times) / 1e6
#d

# %% [markdown]
# # 6. Julia (built-in)

# %% [markdown]
# ## Written directly in Julia, not in C!

# %%
@which sum(a)
# Out:
# sum(a::AbstractArray; dims) in Base at reducedim.jl:652

# %%
j_bench = @benchmark sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     3.226 ms (0.00% GC)
#   median time:      3.395 ms (0.00% GC)
#   mean time:        3.534 ms (0.00% GC)
#   maximum time:     6.959 ms (0.00% GC)
#   --------------
#   samples:          1412
#   evals/sample:     1

# %%
d["Julia built-in"] = minimum(j_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 5 entries:
#   "C"               => 10.1223
#   "Python numpy"    => 3.62204
#   "Python built-in" => 1285.23
#   "Julia built-in"  => 3.22588
#   "C -ffast-math"   => 3.59282

# %% [markdown]
# # 7. Julia (hand-written)

# %%
function mysum(A)
    s = 0.0 # s = zero(eltype(a))
    for a in A
        s += a
    end
    s
end
# Out:
# mysum (generic function with 1 method)

# %%
j_bench_hand = @benchmark mysum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     10.299 ms (0.00% GC)
#   median time:      10.874 ms (0.00% GC)
#   mean time:        11.038 ms (0.00% GC)
#   maximum time:     14.079 ms (0.00% GC)
#   --------------
#   samples:          453
#   evals/sample:     1

# %%
d["Julia hand-written"] = minimum(j_bench_hand.times) / 1e6
d
# Out:
# Dict{Any,Any} with 6 entries:
#   "C"                  => 10.1223
#   "Python numpy"       => 3.62204
#   "Julia hand-written" => 10.2988
#   "Python built-in"    => 1285.23
#   "Julia built-in"     => 3.22588
#   "C -ffast-math"      => 3.59282

# %% [markdown]
# # 8. Julia (hand-writteh w. simd)

# %%
function mysum_simd(A)
    s = 0.0 # s = zero(eltype(A))
    @simd for a in A
        s += a
    end
    s
end
# Out:
# mysum_simd (generic function with 1 method)

# %%
j_bench_hand_simd = @benchmark mysum_simd($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     3.179 ms (0.00% GC)
#   median time:      3.297 ms (0.00% GC)
#   mean time:        3.343 ms (0.00% GC)
#   maximum time:     4.841 ms (0.00% GC)
#   --------------
#   samples:          1493
#   evals/sample:     1

# %%
mysum_simd(a)
# Out:
# 4.998715496980467e6

# %%
d["Julia hand-written simd"] = minimum(j_bench_hand_simd.times) / 1e6
d
# Out:
# Dict{Any,Any} with 7 entries:
#   "Julia hand-written simd" => 3.17858
#   "C"                       => 10.1223
#   "Python numpy"            => 3.62204
#   "Julia hand-written"      => 10.2988
#   "Python built-in"         => 1285.23
#   "Julia built-in"          => 3.22588
#   "C -ffast-math"           => 3.59282

# %% [markdown]
# # Summary

# %%
for (key, value) in sort(collect(d), by=last)
    println(rpad(key, 25, "."), lpad(round(value; digits=1), 6, "."))
end
# Out:
# Julia hand-written simd.....3.2
# Julia built-in..............3.2
# C -ffast-math...............3.6
# Python numpy................3.6
# C..........................10.1
# Julia hand-written.........10.3
# Python built-in..........1285.2
